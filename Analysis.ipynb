# %% [markdown]
#                                 Importing library OS and data source file

# %%
import os

# %%
for dirname, _, filenames in os.walk('/home/alikhan/Desktop/Data/Correlation/Source'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/alikhan/Desktop/Data/Correlation/Source/Survey.csv

# %%
file_path = '/home/alikhan/Desktop/Data/Correlation/Source/Survey.csv'

# %% [markdown]
#                                 Importing Pandas,Matplotlib.pyplot, Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Setting up dataframe

# %%
df = pd.read_csv(file_path)

# %% [markdown]
#                                 Dataframe overall information

# %% [markdown]
# First 10 rows

# %%
df.head(10)
# Out:
#    Номер      Отметка времени 1. Сіздің жасыңыз?\n1. Ваш возраст?\n  \
# 0      1  11/20/2024 17:04:24                                 45-62
# 1      2  11/20/2024 17:40:41                                 18-35
# 2      3  11/20/2024 17:41:16                                   NaN
# 3      4  11/20/2024 18:06:51                                 45-62
# 4      5   11/21/2024 4:28:10                                 36-44
# 5      6   11/21/2024 4:29:35                                 36-44
# 6      7   11/21/2024 4:32:48                                 36-44
# 7      8   11/21/2024 4:38:16                                 36-44
# 8      9   11/21/2024 4:40:15                                 18-35
# 9     10   11/21/2024 4:42:57                                 36-44
#
#   2. Жынысыңыз\n2. Ваш пол?  \
# 0         Ер адам / Мужчина
# 1         Ер адам / Мужчина
# 2                       NaN
# 3         Ер адам / Мужчина
# 4         Ер адам / Мужчина
# 5       Әйел адам / Женщина
# ...

# %% [markdown]
#                                             Columns data type

# %%
df.dtypes
# Out:
# Номер                                                                                                                                                                                                                                                                int64
# Отметка времени                                                                                                                                                                                                                                                     object
# 1. Сіздің жасыңыз?\n1. Ваш возраст?\n                                                                                                                                                                                                                               object
# ...

# %% [markdown]
#                                     Null values in dataset

# %%
df.isnull().sum()
# Out:
# Номер                                                                                                                                                                                                                                                                0
# Отметка времени                                                                                                                                                                                                                                                      0
# 1. Сіздің жасыңыз?\n1. Ваш возраст?\n                                                                                                                                                                                                                               18
# ...

# %% [markdown]
#                                     All Null values sum in dataset

# %%
df.isnull().sum().sum()
# Out:
# 566

# %%
df.describe()
# Out:
#             Номер
# count  600.000000
# mean   300.500000
# std    173.349358
# min      1.000000
# 25%    150.750000
# 50%    300.500000
# 75%    450.250000
# max    600.000000

# %% [markdown]
#                                             Sampled data

# %%
spl = pd.DataFrame({'Man': [289807,141781,176298],
                   'Woman': [322191, 147048, 226985]},
                  index=(['18-25', '26-44','45-62']))

# %%
spl
# Out:
#           Man   Woman
# 18-25  289807  322191
# 26-44  141781  147048
# 45-62  176298  226985

# %%
spl.dtypes
# Out:
# Man      int64
# Woman    int64
# dtype: object
