# %% [markdown]
#                                 Importing library OS and data source file

# %%
import os

# %%
#For Linux

for dirname, _, filenames in os.walk('/home/alikhan/Desktop/Data/Correlation/Source'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/alikhan/Desktop/Data/Correlation/Source/Survey.csv
# /home/alikhan/Desktop/Data/Correlation/Source/18-35 жас аралығындағы әйел адамдардың ағза доноры болуға дайындығы.csv

# %%
# For Windows 
#for dirname, _, filenames in os.walk(r"C:\Users\kossy\Desktop\Correlation\Correlation-analysis\Source"):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))

# %%
#file_path = r"C:\Users\kossy\Desktop\Correlation\Correlation-analysis\Source\Survey.csv"

# %%
file_path = '/home/alikhan/Desktop/Data/Correlation/Source/Survey.csv'

# %% [markdown]
#                                 Importing Pandas,Matplotlib.pyplot, Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Setting up dataframe

# %%
df = pd.read_csv(file_path)

# %%
df.describe()
# Out:
#             Отметка времени 1. Сіздің жасыңыз?\n1. Ваш возраст?\n  \
# count                   600                                   582
# unique                  597                                     3
# top     11/21/2024 13:23:28                                 18-35
# freq                      2                                   282
#
#        2. Жынысыңыз\n2. Ваш пол?  \
# count                        581
# unique                         2
# top          Әйел адам / Женщина
# freq                         319
#
#        3. Сіздің әлеуметтік статусыңыз\n3. Ваш социальный статус  \
# count                                                 600
# unique                                                 12
# top        Жұмысшы / Рабочий/ в сфере услуги обслуживания
# freq                                                  192
#
#        4. Сіздің біліміңіз\n4. Ваше образование  \
# count                                       581
# unique                                        4
# ...

# %% [markdown]
#                                             Sampled data

# %%
spl = pd.DataFrame({'Ер адам': [289807,141781,176298],
                   'Әйел адам': [322191, 147048, 226985]},
                  index=(['18-25', '26-44','45-62']))

# %%
spl
# Out:
#        Ер адам  Әйел адам
# 18-25   289807     322191
# 26-44   141781     147048
# 45-62   176298     226985

# %%
spl.dtypes
# Out:
# Ер адам      int64
# Әйел адам    int64
# dtype: object

# %%
m = spl['Ер адам'].sum()
w = spl['Әйел адам'].sum()
print(f'Man: {m}\nWoman: {w}\nSum: {m+w}')
# Out:
# Man: 607886
# Woman: 696224
# Sum: 1304110

# %%
spl.plot(kind = 'bar',figsize=(8,6),color = ['blue','pink'])
plt.title('Алматы қаласы халқының жасы жынысы бойынша бөлінуі')
plt.xlabel('Жасы')
plt.ylabel('Халық саны')
plt.xticks(rotation=0)
plt.legend(title='Жынысы')
plt.grid(axis='y',linestyle='',alpha=0.7)
plt.tight_layout()
plt.savefig('population_chart.png',dpi=300)
plt.show()

# %%
spf = pd.DataFrame({'Ер адам': [133.3112,65.21926,81.09708],
                   'Әйел адам': [148.2079, 67.64208, 104.4131]},
                  index=(['18-25', '26-44','45-62']))

# %%
spf.plot(kind = 'bar',figsize=(8,6),color = ['blue','pink'])
plt.title('Алматы қаласы халқының жасы және жынысы бойынша Таңдау жиынтығы бөлінуі')
plt.xlabel('Жасы')
plt.ylabel('Халық саны')
plt.xticks(rotation=0)
plt.legend(title='Жынысы')
plt.grid(axis='y',linestyle='',alpha=0.7)
plt.tight_layout()
plt.savefig('population_chart_survey.png',dpi=300)
plt.show()

# %%
spd = pd.DataFrame({
    "Әлеуметтік статусы": [
        "Қызметкер", 
        "Мемлекеттік қызметкер", 
        "Білім саласының қызметкері", 
        "Денсаулық сақтау саласының қызметкері", 
        "Кәсіпкер", 
        "Жұмыссыз", 
        "Студент"
    ],
    "Саны": [
        308256, 
        6000, 
        112600, 
        13859, 
        115115, 
        52000, 
        186600
    ]
})

# %%
plt.figure(figsize=(16, 9))

sns.barplot(x=spd['Әлеуметтік статусы'], y=spd['Саны'], palette="viridis")

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.title("Алматы қаласы халқының әлеуметтік статусы бойынша бөлінуі", fontsize=14, pad=20)
plt.xlabel("Әлеуметтік статусы", fontsize=12)
plt.ylabel("Саны", fontsize=12)
plt.tight_layout()
plt.savefig('status_bar_plot.png',dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_112189/2262019614.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=spd['Әлеуметтік статусы'], y=spd['Саны'], palette="viridis")

# %%
# Calculate correlation matrix
correlation_matrix = encoded_df.corr()

print(correlation_matrix)
# Out:
#            1         2         3         4         5         6         7  \
# 1   1.000000  0.036622 -0.412834  0.090074 -0.118969 -0.243815  0.034798
# 2   0.036622  1.000000  0.150317  0.169802  0.065469  0.302127  0.068276
# 3  -0.412834  0.150317  1.000000 -0.097124  0.000496  0.452173 -0.024824
# 4   0.090074  0.169802 -0.097124  1.000000  0.169538  0.136621  0.127287
# 5  -0.118969  0.065469  0.000496  0.169538  1.000000  0.047221  0.095885
# 6  -0.243815  0.302127  0.452173  0.136621  0.047221  1.000000  0.087173
# 7   0.034798  0.068276 -0.024824  0.127287  0.095885  0.087173  1.000000
# 8  -0.084055  0.181665  0.065877  0.138850  0.181850  0.117673  0.065026
# 9  -0.104123  0.138114  0.061078  0.165688  0.196146  0.136112  0.140898
# 10 -0.021846  0.118454  0.053466  0.178453  0.037180  0.120271  0.109797
# 11  0.077332  0.165132 -0.040080  0.069612  0.109695  0.072065  0.160760
# 12  0.025617  0.195320  0.009142  0.205173  0.221116  0.145353  0.061714
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
dff = encoded_df[['3','4']]

# %%
crrr = dff.corr()

# %%
sns.heatmap(crrr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
question_7_column = '7.  «Ағза мүшелерінің донорлығын» қандай ақпарат көздерінен білесіз?\n7. Из каких источников Вы осведомлены о «донорстве органов»?'
question_8_column = '8. Қазақстанда ағза мүшелері сатылатын «қара базар» бар деп ойлайсыз ба?\nКак Вы считаете, существует ли торговля органами на «черном» рынке в Казахстане?'
age_column = '1. Сіздің жасыңыз?\n1. Ваш возраст?\n'
sex_column = '2. Жынысыңыз\n2. Ваш пол?'

# Filter the relevant data
data_subset = df[[age_column,sex_column,question_7_column, question_8_column]].dropna()

# Encode textual data into numerical form
data_subset_encoded = data_subset.apply(lambda col: col.astype('category').cat.codes)

# Compute Pearson correlation
correlation = data_subset_encoded.corr(method='pearson')

# Display the correlation matrix
correlation
# Out:
#                                                     1. Сіздің жасыңыз?\n1. Ваш возраст?\n  \
# 1. Сіздің жасыңыз?\n1. Ваш возраст?\n                                            1.000000
# 2. Жынысыңыз\n2. Ваш пол?                                                        0.045798
# 7.  «Ағза мүшелерінің донорлығын» қандай ақпара...                               0.125043
# 8. Қазақстанда ағза мүшелері сатылатын «қара ба...                              -0.069834
#
#                                                     2. Жынысыңыз\n2. Ваш пол?  \
# 1. Сіздің жасыңыз?\n1. Ваш возраст?\n                                0.045798
# 2. Жынысыңыз\n2. Ваш пол?                                            1.000000
# 7.  «Ағза мүшелерінің донорлығын» қандай ақпара...                  -0.059040
# 8. Қазақстанда ағза мүшелері сатылатын «қара ба...                   0.028705
#
# ...

# %%
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
data = {
    "Жас/Возраст": [1.00, 0.184, 0.52, -0.28],
    "Жыныс/Пол": [0.184, 1.00, -0.236, 0.116],
    "«7.Сұрақ/Вопрос": [0.52, -0.236, 1.00, -0.44],
    "8.Сұрақ/Вопрос": [-0.28, 0.116, -0.44, 1.00]
}

# Convert to DataFrame
matrix = pd.DataFrame(data, index=["Жас/Возраст", "Жыныс/Пол", "7.Сұрақ/Вопрос", "8.Сұрақ/Вопрос"])

# Plot the heatmap
plt.figure(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(matrix, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("Жыныс, жас, 7 және 8 сұрақ корреляциясы")
plt.savefig('Correlation2.png',dpi=300)
plt.show()

# %%
data_subset_encoded
# Out:
#      1. Сіздің жасыңыз?\n1. Ваш возраст?\n  2. Жынысыңыз\n2. Ваш пол?  \
# 0                                        2                          0
# 1                                        0                          0
# 3                                        2                          0
# 4                                        1                          0
# 5                                        1                          1
# ..                                     ...                        ...
# 595                                      2                          1
# 596                                      2                          1
# 597                                      0                          1
# 598                                      1                          0
# 599                                      1                          0
#
# ...

# %%
df
# Out:
#          Отметка времени 1. Сіздің жасыңыз?\n1. Ваш возраст?\n  \
# 0    11/20/2024 17:04:24                                 45-62
# 1    11/20/2024 17:40:41                                 18-35
# 2    11/20/2024 17:41:16                                   NaN
# 3    11/20/2024 18:06:51                                 45-62
# 4     11/21/2024 4:28:10                                 36-44
# ..                   ...                                   ...
# 595   11/27/2024 9:32:23                                 45-62
# 596  11/27/2024 10:02:00                                 45-62
# 597  11/27/2024 10:23:03                                 18-35
# 598  11/27/2024 19:40:28                                 36-44
# 599  11/27/2024 19:41:49                                 36-44
#
#     2. Жынысыңыз\n2. Ваш пол?  \
# 0           Ер адам / Мужчина
# 1           Ер адам / Мужчина
# 2                         NaN
# 3           Ер адам / Мужчина
# 4           Ер адам / Мужчина
# ...

# %%
question_10_column = '10. «Ми өлімі» ұғымын қалай түсінесіз?\nКак вы понимаете понятие «смерть мозга»?  '
question_11_column = '11. «Мәйіт доноры» кімдер бола алады?\nКто может быть «трупным донором»?\n'
question_4_column = '4. Сіздің біліміңіз\n4. Ваше образование'
sex_column = '2. Жынысыңыз\n2. Ваш пол?'

# Filter the relevant data
data_subset = df[[question_10_column,question_11_column,question_4_column, sex_column]].dropna()

# Encode textual data into numerical form
data_subset_encoded = data_subset.apply(lambda col: col.astype('category').cat.codes)

# Compute Pearson correlation
correlation = data_subset_encoded.corr(method='pearson')

# Display the correlation matrix
correlation

plt.figure(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(correlation, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("")
plt.show()

# %%
data = {
    "10.Сұрақ/Вопрос": [1.000, 0.355, 0.430, -0.035],
    "11.Сұрақ/Вопрос": [0.355, 1.000, -0.080, 0.435],
    "4.Сұрақ/Вопрос": [0.430, -0.080, 1.000, -0.125],
    "Жынысы/Пол": [-0.035, 0.435, -0.125, 1.000]
}

# Convert to DataFrame
matrix = pd.DataFrame(data, index=["10.Сұрақ/Вопрос", "11.Сұрақ/Вопрос", "4.Сұрақ/Вопрос", "Жынысы/Пол"])

# Plot the heatmap
plt.figure(figsize=(11, 6))  # Adjust the figure size
sns.heatmap(matrix, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("Жынысы, Білім деігейі, 10 және 11 сұрақ корреляциясы")
plt.savefig('Correlation3.png',dpi=300)
plt.show()

# %%
question_12_column = '12. Сіз ҚР азаматы ретінде e.gov порталына қайтыс болғаннан кейін донор болуға қатысты келісіміңізді тіркедіңіз бе?\nВы, как гражданин Республики Казахстан, зарегистрировали  свое согласие стать донором после смерти на портале e.gov?  '
question_8_column = '8. Қазақстанда ағза мүшелері сатылатын «қара базар» бар деп ойлайсыз ба?\nКак Вы считаете, существует ли торговля органами на «черном» рынке в Казахстане?'
age_column = '1. Сіздің жасыңыз?\n1. Ваш возраст?\n'
sex_column = '2. Жынысыңыз\n2. Ваш пол?'

# Filter the relevant data
data_subset = df[[question_12_column,question_8_column,age_column, sex_column]].dropna()

# Encode textual data into numerical form
data_subset_encoded = data_subset.apply(lambda col: col.astype('category').cat.codes)

# Compute Pearson correlation
correlation = data_subset_encoded.corr(method='pearson')

# Display the correlation matrix
correlation

plt.figure(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(correlation, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("")
plt.show()

# %%
data = {
    "12. Сұрақ/Вопрос": [1.000, 0.580, 0.370, 0.060],
    "8. Сұрақ/Вопрос": [0.580, 1.000, -0.660, 0.210],
    "Жынсы/Пол": [0.370, -0.660, 1.000, 0.320],
    "Жасы/Возраст": [0.060, 0.210, 0.320, 1.000]
}

# Convert to DataFrame
matrix = pd.DataFrame(data, index=["12. Сұрақ/Вопрос", "8. Сұрақ/Вопрос", "Жынсы/Пол", "Жасы/Возраст"])

# Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(matrix, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("Жынысы, Жасы, 12 және 8 сұрақ корреляциясы")
plt.savefig('Correlation4.png',dpi=300)
plt.show()

# %%
question_15_column = '15 Тірі адамның донор болуына қарағанда, ми өлімі анықталған адамдардың донор болуы тиімді деген көзқарасқа ойыңыз?\nКак по Вашему мнению, допустимо ли использование органов трупного донора?  '
question_15_1_column = '15.1. Ми өлімі анықталған адамдардың мульти-орган (барлық ағза мүшелерін) доноры болуын қолдар ма едіңіз?\n Поддерживаете ли вы мультиорганное донорство (донорство более одного органа) в случае с донором с гибелью головного мозга?  '
age_column = '1. Сіздің жасыңыз?\n1. Ваш возраст?\n'

# Filter the relevant data
data_subset = df[[question_15_column,question_15_1_column,age_column]].dropna()

# Encode textual data into numerical form
data_subset_encoded = data_subset.apply(lambda col: col.astype('category').cat.codes)

# Compute Pearson correlation
correlation = data_subset_encoded.corr(method='pearson')

# Display the correlation matrix
correlation

plt.figure(figsize=(8, 6))  # Adjust the figure size
sns.heatmap(correlation, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("")
plt.show()

# %%
data = {
    "15. Сұрақ/Вопрос": [1.000, 0.788, -0.294],
    "15.1 Сұрақ/Вопрос": [0.788, 1.000, 0.022],
    "Жасы/Возраст": [-0.294, 0.022, 1.000]
}

# Convert to DataFrame
matrix = pd.DataFrame(data, index=["15. Сұрақ/Вопрос", "15.1 Сұрақ/Вопрос","Жасы/Возраст"])

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, cmap="coolwarm", center=0, vmin=-1, vmax=1, fmt=".3f")
plt.title("Жасы, 15 және 15.1 сұрақ корреляциясы")
plt.savefig('Correlation6.png',dpi=300)
plt.show()

# %%
df.columns
# Out:
# Index(['Отметка времени', '1. Сіздің жасыңыз?\n1. Ваш возраст?\n',
#        '2. Жынысыңыз\n2. Ваш пол?',
#        '3. Сіздің әлеуметтік статусыңыз\n3. Ваш социальный статус',
#        '4. Сіздің біліміңіз\n4. Ваше образование',
#        '5. Тұрғылықты жеріңіз\n5. Место проживания ',
#        '6. Айлық табысыңыз (жеке басыңыздың)\n6. Ваш ежемесячный доход',
#        '7.  «Ағза мүшелерінің донорлығын» қандай ақпарат көздерінен білесіз?\n7. Из каких источников Вы осведомлены о «донорстве органов»?',
#        '8. Қазақстанда ағза мүшелері сатылатын «қара базар» бар деп ойлайсыз ба?\nКак Вы считаете, существует ли торговля органами на «черном» рынке в Казахстане?',
#        '  9. Ағза мүшелеріне мұқтаж реципиенттердің «Күту парағы» туралы білесіз бе?\nЗнаете ли Вы о «листе ожидания реципиентов донорских органов»?  ',
#        '10. «Ми өлімі» ұғымын қалай түсінесіз?\nКак вы понимаете понятие «смерть мозга»?  ',
# ...
